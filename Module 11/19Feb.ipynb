# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a micro web framework written in Python. It is classified as a micro-framework because it does not require particular tools or libraries, allowing developers to use their preferred tools and libraries when building web applications. Flask is based on the Werkzeug WSGI toolkit and the Jinja2 template engine.
#
# Some advantages of Flask Framework are:
#
# Lightweight: Flask is a lightweight framework that is easy to learn and use. It has a small core and is highly extensible, allowing developers to add only the features they need.
#
# Flexibility: Flask provides developers with a great deal of flexibility in terms of how they structure their applications. It doesn't impose any specific application structure or require the use of particular libraries, allowing developers to choose the approach that works best for their project.
#
# Easy to get started: Flask has a simple and easy-to-use API that makes it easy for developers to get started building web applications quickly.
#
# Integrated development server: Flask comes with a built-in development server that is useful for testing and debugging applications.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello_world():
    return 'Hello World!'

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ![Screenshot%202023-02-28%20224521.png](attachment:Screenshot%202023-02-28%20224521.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing in Flask refers to the process of defining URL routes that map to specific functions in your Flask application. This is done using the @app.route() decorator in your Python code.
#
# We use app routes in Flask to handle incoming HTTP requests from clients, and to generate appropriate responses. Each app route corresponds to a specific URL pattern, which is matched against the requested URL to determine which function should be called to handle the request.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ### Company Name: ABC Corporation
# ### Location: India
# ### Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def company_details():
    return 'Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999'

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ![Screenshot%202023-02-28%20225742.png](attachment:Screenshot%202023-02-28%20225742.png)

# %% [markdown]
# ![Screenshot%202023-02-28%20225841.png](attachment:Screenshot%202023-02-28%20225841.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# In Flask, the url_for() function is used for URL building. This function generates a URL for the specified endpoint, based on the arguments passed to it.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/hello/<name>')
def hello(name):
    return 'Hello, %s!' % name

@app.route('/user/<username>')
def show_user_profile(username):
    return 'User %s' % username

with app.test_request_context():
    print(url_for('hello', name='John'))
    print(url_for('show_user_profile', username='Jane Doe'))

# %% [markdown]
# In this example, we define two routes /hello/<name> and /user/<username> that take parameters in their URL paths. We then use the url_for() function to generate URLs for these endpoints, passing in the appropriate parameters as arguments.
